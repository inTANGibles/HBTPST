# %%
import pandas as pd
import numpy as np
import os
import datetime
import time
from tqdm import tqdm
import math

from utils import utils,myplot

import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv(r'..\wifi_track_data\dacang\track_data\dacang_track_data_final.csv')
df.t = pd.to_datetime(df.t)
mac_list = df.m.unique()

#get path & pos data
df_wifipos = pd.read_csv('..\wifi_track_data/dacang/pos_data/wifi_pos.csv')
df_path = pd.read_csv('..\wifi_track_data/dacang/pos_data/path_pos.csv')

# %load_ext autoreload
# %autoreload 2

# %%
for m in tqdm(mac_list):
    df_now = df[df.m == m]
    myplot.Track2D_Restored(df_now,df_wifipos,df_path,absolute=False,pureMode = True,
                        showfig=False,
                        save_fig=f'wifi_track_data/dacang/track_data/track_2D_jpg/{m}.jpg',
                        )
# Out:
#   0%|          | 0/1343 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 for m in tqdm(mac_list):
#       2     df_now = df[df.m == m]
# ----> 3     myplot.Track2D_Restored(df_now,df_wifipos,df_path,absolute=False,pureMode = True,
#       4                         showfig=False,
#       5                         save_fig=f'wifi_track_data/dacang/track_data/track_2D_jpg/{m}.jpg',
#       6                         )
#       7 print(df.columns)
#
# File D:\TangYe\HBTPST\utils\myplot.py:754, in Track2D_Restored(df, df_wifipos, df_path, save_counts, showfig, save_fig, absolute, pureMode)
#     750     np.save(folder_path + f'/{save_counts}_stay_pos.npy',stay_pos)
#     751     np.save(folder_path + f'/{save_counts}_stay_count.npy',stay_count)
# --> 754 Track_2D(pass_path,
#     755          pass_count,
#     756          stay_pos,
#     757          stay_count,
#     758          absolute = absolute,
#     759          pureMode = pureMode,
#     760          showfig = showfig,
#     761          save_fig = save_fig)
#
# File D:\TangYe\HBTPST\utils\myplot.py:868, in Track_2D(pass_path, pass_count, stay_pos, stay_count, absolute, pureMode, showfig, save_fig)
#     847     fig.update_layout(
#     848         xaxis=dict(range=[0, 400],
#     849                    showgrid = False,
#    (...)
#     865
#     866     )
#     867 if save_fig != '':
# --> 868     fig.write_image(save_fig, engine='orca')
#     869 #pio.write_image(fig,'111.jpg')
#     870 if showfig:
#
# File C:\ProgramData\anaconda3\envs\meirlenv\lib\site-packages\plotly\basedatatypes.py:3835, in BaseFigure.write_image(self, *args, **kwargs)
#    3775 """
#    3776 Convert a figure to a static image and write it to a file or writeable
#    3777 object
#    (...)
#    3831 None
#    3832 """
#    3833 import plotly.io as pio
# -> 3835 return pio.write_image(self, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\meirlenv\lib\site-packages\plotly\io\_kaleido.py:266, in write_image(fig, file, format, scale, width, height, validate, engine)
#     250             raise ValueError(
#     251                 """
#     252 Cannot infer image type from output path '{file}'.
#    (...)
#     260                 )
#     261             )
#     263     # Request image
#     264     # -------------
#     265     # Do this first so we don't create a file if image conversion fails
# --> 266     img_data = to_image(
#     267         fig,
#     268         format=format,
#     269         scale=scale,
#     270         width=width,
#     271         height=height,
#     272         validate=validate,
#     273         engine=engine,
#     274     )
#     276     # Open file
#     277     # ---------
#     278     if path is None:
#     279         # We previously failed to make sense of `file` as a pathlib object.
#     280         # Attempt to write to `file` as an open file descriptor.
#
# File C:\ProgramData\anaconda3\envs\meirlenv\lib\site-packages\plotly\io\_kaleido.py:115, in to_image(fig, format, width, height, scale, validate, engine)
#     111 if engine == "orca":
#     112     # Fall back to legacy orca image export path
#     113     from ._orca import to_image as to_image_orca
# --> 115     return to_image_orca(
#     116         fig,
#     117         format=format,
#     118         width=width,
#     119         height=height,
#     120         scale=scale,
#     121         validate=validate,
#     122     )
#     123 elif engine != "kaleido":
#     124     raise ValueError(
#     125         "Invalid image export engine specified: {engine}".format(
#     126             engine=repr(engine)
#     127         )
#     128     )
#
# File C:\ProgramData\anaconda3\envs\meirlenv\lib\site-packages\plotly\io\_orca.py:1445, in to_image(fig, format, width, height, scale, validate)
#    1393 """
#    1394 Convert a figure to a static image bytes string
#    1395
#    (...)
#    1441     The image data
#    1442 """
#    1443 # Make sure orca sever is running
#    1444 # -------------------------------
# -> 1445 ensure_server()
#    1447 # Handle defaults
#    1448 # ---------------
#    1449 # Apply configuration defaults to unspecified arguments
#    1450 if format is None:
#
# File C:\ProgramData\anaconda3\envs\meirlenv\lib\site-packages\plotly\io\_orca.py:1296, in ensure_server()
#    1293 if not config.server_url:
#    1294     # Validate orca executable only if server_url is not provided
#    1295     if status.state == "unvalidated":
# -> 1296         validate_executable()
#    1297     # Acquire lock to make sure that we keep the properties of orca_state
#    1298     # consistent across threads
#    1299     with orca_lock:
#    1300         # Cancel the current shutdown timer, if any
#
# File C:\ProgramData\anaconda3\envs\meirlenv\lib\site-packages\plotly\io\_orca.py:982, in validate_executable()
#     979     formatted_path = path.replace(os.pathsep, "\n    ")
#     981     if executable is None:
# --> 982         raise ValueError(
#     983             """
#     984 The orca executable is required to export figures as static images,
#     985 but it could not be found on the system path.
#     986
#     987 Searched for executable '{executable}' on the following path:
#     988     {formatted_path}
#     989
#     990 {instructions}""".format(
#     991                 executable=config.executable,
#     992                 formatted_path=formatted_path,
#     993                 instructions=install_location_instructions,
#     994             )
#     995         )
#     997     # Check if we should run with Xvfb
#     998     # --------------------------------
#     999     xvfb_args = [
#    1000         "--auto-servernum",
#    1001         "--server-args",
#    1002         "-screen 0 640x480x24 +extension RANDR +extension GLX",
#    1003         executable,
#    1004     ]
#
# ValueError:
# The orca executable is required to export figures as static images,
# but it could not be found on the system path.
#
# Searched for executable 'orca' on the following path:
#     C:\ProgramData\anaconda3\envs\meirlenv
#     C:\ProgramData\anaconda3\envs\meirlenv\Library\mingw-w64\bin
#     C:\ProgramData\anaconda3\envs\meirlenv\Library\usr\bin
#     C:\ProgramData\anaconda3\envs\meirlenv\Library\bin
#     C:\ProgramData\anaconda3\envs\meirlenv\Scripts
#     C:\ProgramData\anaconda3\envs\meirlenv\bin
#     C:\ProgramData\anaconda3\condabin
#     C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\bin
#     C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\libnvvp
#     C:\Program Files\Python310\Scripts
#     C:\Program Files\Python310
#     C:\windows\system32
#     C:\windows
#     C:\windows\System32\Wbem
#     C:\windows\System32\WindowsPowerShell\v1.0
#     C:\windows\System32\OpenSSH
#     C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common
#     C:\Program Files\dotnet
#     C:\Program Files\NVIDIA Corporation\Nsight Compute 2023.1.1
#     C:\Program Files\Git\cmd
#     C:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.36.32532\bin\Hostx64\x64
#     C:\Program Files\CMake\bin
#     D:\FengYiheng\ProgramFiles\ffmpeg\bin
#     D:\FengYiheng\ProgramFiles\COLMAP-3.8-windows-cuda
#     D:\FengYiheng\ProgramFiles\Ninja
#     C:\Program Files\VisualSVNServer\bin
#     C:\Program Files\TortoiseSVN\bin
#     C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR
#     C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\bin
#     C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\libnvvp
#     C:\Program Files\Python310\Scripts
#     C:\Program Files\Python310
#     C:\windows\system32
#     C:\windows
#     C:\windows\System32\Wbem
#     C:\windows\System32\WindowsPowerShell\v1.0
#     C:\windows\System32\OpenSSH
#     C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common
#     C:\Program Files\dotnet
#     C:\Program Files\NVIDIA Corporation\Nsight Compute 2023.1.1
#     C:\Program Files\Git\cmd
#     C:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.36.32532\bin\Hostx64\x64
#     C:\Program Files\CMake\bin
#     D:\FengYiheng\ProgramFiles\ffmpeg\bin
#     D:\FengYiheng\ProgramFiles\COLMAP-3.8-windows-cuda
#     D:\FengYiheng\ProgramFiles\Ninja
#     C:\Program Files\VisualSVNServer\bin
#     C:\Program Files\TortoiseSVN\bin
#     C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR
#     C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps
#     C:\Users\Administrator\AppData\Local\Programs\Microsoft VS Code\bin
#     C:\Program Files\Python310
#     C:\Program Files
#     C:\Users\Administrator\Downloads\exiftool-12.98_64\exiftool-12.98_64
#     C:\Users\Administrator\AppData\Local\GitHubDesktop\bin
#     C:\ProgramData\Anaconda3\Library\Bin
#
# If you haven't installed orca yet, you can do so using conda as follows:
#
#     $ conda install -c plotly plotly-orca
#
# Alternatively, see other installation methods in the orca project README at
# https://github.com/plotly/orca
#
# After installation is complete, no further configuration should be needed.
#
# If you have installed orca, then for some reason plotly.py was unable to
# locate it. In this case, set the `plotly.io.orca.config.executable`
# property to the full path of your orca executable. For example:
#
#     >>> plotly.io.orca.config.executable = '/path/to/orca'
#
# After updating this executable property, try the export operation again.
# If it is successful then you may want to save this configuration so that it
# will be applied automatically in future sessions. You can do this as follows:
#
#     >>> plotly.io.orca.config.save()
#
# If you're still having trouble, feel free to ask for help on the forums at
# https://community.plot.ly/c/api/python

# %%
myplot.Track2D_Restored(df,df_wifipos,df_path,save_counts='total')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 myplot.Track2D_Restored(df,df_wifipos,df_path,save_counts='total')
#
# File D:\TangYe\HBTPST\utils\myplot.py:742, in Track2D_Restored(df, df_wifipos, df_path, save_counts, showfig, save_fig, absolute, pureMode)
#     740 for mac in mac_list:
#     741     df_now = utils.GetDfNow(df,mac)
# --> 742     _getPathAndStay(df_now,df_wifipos,df_path,pass_path,pass_count,stay_pos,stay_count)
#     744 if save_counts != '':
#     745     folder_path = os.path.join('wifi_track_data/dacang/track_data/',str(date)+f'/{save_counts}')
#
# File D:\TangYe\HBTPST\utils\myplot.py:713, in _getPathAndStay(df_now, df_wifipos, df_path, pass_path, pass_count, stay_pos, stay_count)
#     711 paths = utils._getPath(wifi_last,row.a,df_path)
#     712 last_loc = 0
# --> 713 for i in range(len(paths)):
#     714     loc_str = paths[i].split(':')
#     715     loc = [float(loc_str[0]),float(loc_str[1])]
#
# TypeError: object of type 'NoneType' has no len()

# %%
myplot.Track2D_Restored(df_resi,df_wifipos,df_path,show_freq=True,save='resi')
# Out:
#   0%|          | 0/766 [00:00<?, ?it/s]
# 100%|██████████| 766/766 [56:00<00:00,  4.39s/it]

# %%
myplot.Track2D_Restored(df_resi[df_resi.id_cluster == 0],df_wifipos,df_path,show_freq=True,save='resi_0')
# Out:
#   0%|          | 0/190 [00:00<?, ?it/s]
# 100%|██████████| 190/190 [10:47<00:00,  3.41s/it]

# %%
myplot.Track2D_Restored(df_resi[df_resi.id_cluster == 1],df_wifipos,df_path,show_freq=True,save='resi_1')
# Out:
#   0%|          | 0/355 [00:00<?, ?it/s]
# 100%|██████████| 355/355 [19:38<00:00,  3.32s/it]

# %%
myplot.Track2D_Restored(df_resi[df_resi.id_cluster == 2],df_wifipos,df_path,show_freq=True,save='resi_2')
# Out:
# 100%|██████████| 121/121 [20:06<00:00,  9.97s/it]

# %%
myplot.Track2D_Restored(df_resi[df_resi.id_cluster == 3],df_wifipos,df_path,show_freq=True,save='resi_3')
# Out:
# 100%|██████████| 100/100 [05:12<00:00,  3.12s/it]

# %%
myplot.Track2D_Restored(df_tour,df_wifipos,df_path,show_freq=True,save='tour')
# Out:
#   0%|          | 0/251 [00:00<?, ?it/s]
# 100%|██████████| 251/251 [18:01<00:00,  4.31s/it]

# %%
myplot.Track2D_Restored(df_tour[df_tour.id_cluster == 0],df_wifipos,df_path,show_freq=True,save='tour_0')
# Out:
#   0%|          | 0/77 [00:00<?, ?it/s]
# 100%|██████████| 77/77 [03:33<00:00,  2.78s/it]

# %%
myplot.Track2D_Restored(df_tour[df_tour.id_cluster == 1],df_wifipos,df_path,show_freq=True,save='tour_1')
# Out:
# 100%|██████████| 174/174 [14:27<00:00,  4.98s/it]
